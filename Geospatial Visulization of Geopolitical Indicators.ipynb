# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
from folium import plugins

# %%
pip install rioxarray
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import rioxarray as rxr

# %%
pip install earthpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import earthpy as et

# %%
import earthpy.spatial as es

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim

# %%
import branca

# %%
df = pd.read_csv('/Volumes/My_Files/MBS Course Material/Group for GTS/Geopolitcal Risk 2.csv')

# %%
location = df['Latitude'].mean(), df['Longitude'].mean()

# %%
m1 = folium.Map(location=location,zoom_start=4)

# %%
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i in range(0,len(df)):
    Regions = df['Regions'].iloc[i]
    if Regions == 'Asia':
        color = 'darkblue'
    else:
        color = 'green'

# %%
labels=df['Country'].iloc[i]

# %%
folium.Marker([df['Latitude'].iloc[i],df['Longitude'].iloc[i]],popup=labels,
                 icon=folium.Icon(color=color, icon='university', prefix='fa')).add_to(m1)

# %%
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for index, location_info in df.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Country"]).add_to(m1)

# %%
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i in range(0,len(df)):  
    labels=df['Country'].iloc[i]
    folium.Marker([df['Latitude'].iloc[i],df['Longitude'].iloc[i]],popup=labels,
                 icon=folium.Icon(icon='bar-chart', prefix='fa')).add_to(m1)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
def popup_html(row):
    i = row
    Country =df['Country'].iloc[i] 
    Property_Right_Index=df['Property Right Index'].iloc[i] 
    Curruption_Perception_Index=df['Curruption Perception Index'].iloc[i]
    Percentage_of_GDP_growth_annually  = df['Percentage of GDP growth annually'].iloc[i] 
    Social_Unrest =df['Social Unrest'].iloc[i] 
    Labor_freedom_index  = df['Labor freedom index'].iloc[i]                     
    Monetary_freedom_index  = df['Monetary freedom index'].iloc[i]
    Trade_freedom_index   = df['Trade freedom index'].iloc[i]
    Investment_freedom_index   = df['Investment freedom index'].iloc[i]
    Financial_freedom_index  = df['Financial freedom index'].iloc[i]
    Political_globalization_index   = df['Political globalization index'].iloc[i]
    Social_globalization_index   = df['Social globalization index'].iloc[i]
    Fragile_state_index    = df['Fragile state index'].iloc[i]
    Government_Effectiveness    = df['Government Effectiveness'].iloc[i]
    Social_Progress_Index     = df['Social Progress Index'].iloc[i]
    left_col_color = "#19a7bd"
    right_col_color = "#f2f0d3"
    
    html = """<!DOCTYPE html>
<html>
<head>
<h4 style="margin-bottom:10"; width="200px">{}</h4>""".format(Country) + """
</head>
    <table style="height: 126px; width: 350px;">
<tbody>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Property Right Index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Property_Right_Index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Curruption Perception Index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Curruption_Perception_Index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Percentage of GDP growth annually</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Percentage_of_GDP_growth_annually) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Social Unrest</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Social_Unrest) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Labor freedom index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Labor_freedom_index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Monetary freedom index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Monetary_freedom_index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Trade freedom index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Trade_freedom_index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Investment freedom index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Investment_freedom_index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Financial freedom index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Financial_freedom_index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Political globalization index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Political_globalization_index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Social globalization index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Social_globalization_index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Fragile state index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Fragile_state_index) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Government Effectiveness</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Government_Effectiveness) + """
</tr>
<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Social Progress Index</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Social_Progress_Index) + """
</tr>
</tbody>
</table>
</html>
"""
    return html

# %%
html = popup_html(i)

# %%
popup = folium.Popup(folium.Html(html, script=True), max_width=500)

# %%
folium.Marker([df['Latitude'].iloc[i],df['Longitude'].iloc[i]],
                  popup=popup,icon=folium.Icon(color=color, icon='university', prefix='fa')).add_to(m1)

# %%
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
location = df['Latitude'].mean(), df['Longitude'].mean()
m2 = folium.Map(location=location,zoom_start=5)
for i in range(0,len(df)):
    Regions = df['Regions'].iloc[i]
    if Regions == 'North America':
        color = 'darkblue'
    elif Regions == 'Europe' or Regions == 'Asia' or Regions == 'East Africa':
        color = 'lightbrown'
    else:
        color = 'gray'
        
    html = popup_html(i)
    popup = folium.Popup(folium.Html(html, script=True), max_width=500)
    folium.Marker([df['Latitude'].iloc[i],df['Longitude'].iloc[i]],
                  popup=popup,icon=folium.Icon(color=color, icon='bar-chart', prefix='fa')).add_to(m2)
    
m2
# Out:
# /var/folders/tz/c4w55wbj3x9dyxm2sn_sz57m0000gn/T/ipykernel_27259/1042628725.py:15: UserWarning: color argument of Icon should be one of: {'darkgreen', 'green', 'orange', 'lightred', 'lightgreen', 'black', 'purple', 'blue', 'lightblue', 'lightgray', 'beige', 'white', 'darkred', 'red', 'cadetblue', 'darkpurple', 'gray', 'pink', 'darkblue'}.
#   popup=popup,icon=folium.Icon(color=color, icon='bar-chart', prefix='fa')).add_to(m2)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %%
m2.save("Geopolitical Scenarios.html")
